# %% [markdown]
# ***| Cristian Meichtry (62529) | Juan Martin Rodriguez (62563) |***

# %% [markdown]
# Luego de iterar sobre varios diseños, se probaron dos modelos principales:
#
# ***Primer modelo***: Consta de 4 bloques convolucionales y capas densas finales. Utiliza activaciones SELU, Batch Normalization, Dropout, ruido gaussiano y regularización L2. Optimiza con Adam y clasifica con softmax. Obtuvo un score privado de 0.6954 y un score público de 0.7108.
#
# ***Segundo modelo***: Es una red residual profunda con bloques que integran convoluciones, Batch Normalization y conexiones residuales. Incluye etapas de inicialización, procesamiento intermedio y reducción espacial, seguidas de capas densas con Swish y regularización. También utiliza Adam como optimizador. Este modelo logró un score privado de 0.6766 y un score público de 0.6808.
#
# Por otro lado, se observó que, de manera contraintuitiva, al aplicar data augmentation similar al del TP1, el rendimiento disminuía notablemente, alcanzando scores cercanos a 0.58.

# %%
import numpy as np # linear algebra

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dl-itba-cifar-100-2024-q-1/y_train_fine.npy
# /kaggle/input/dl-itba-cifar-100-2024-q-1/y_train_coarse.npy
# /kaggle/input/dl-itba-cifar-100-2024-q-1/fine_label_names.pck
# /kaggle/input/dl-itba-cifar-100-2024-q-1/coarse_label_names.pck
# /kaggle/input/dl-itba-cifar-100-2024-q-1/x_test.npy
# /kaggle/input/dl-itba-cifar-100-2024-q-1/x_train.npy

# %%
x_train = np.load("/kaggle/input/dl-itba-cifar-100-2024-q-1/x_train.npy")/255.
x_test = np.load("/kaggle/input/dl-itba-cifar-100-2024-q-1/x_test.npy")/255.
y_train_coarse = np.load("/kaggle/input/dl-itba-cifar-100-2024-q-1/y_train_coarse.npy")
y_train_fine = np.load("/kaggle/input/dl-itba-cifar-100-2024-q-1/y_train_fine.npy")

print(y_train_coarse)
print(y_train_fine)
# Out:
# [11 15  4 ...  8  7  1]
# [19 29  0 ...  3  7 73]

# %%
import pickle

with open("/kaggle/input/dl-itba-cifar-100-2024-q-1/fine_label_names.pck", "rb") as f:
    labels_fine = pickle.load(f)
with open("/kaggle/input/dl-itba-cifar-100-2024-q-1/coarse_label_names.pck", "rb") as f:
    labels_coarse = pickle.load(f)

# %%
from matplotlib import pyplot as plt
#%load_ext tensorboard
import keras_cv

# %%
#This code snippet visualizes samples from the training dataset.
#It displays two rows of images with their corresponding labels, each consisting of eight images.

plt.figure(figsize=(10, 10))
cant = 8
for i in range(cant):
    plt.subplot(1, cant, i+1)
    plt.imshow(x_train[i]) #Display the i-th image from the training set
    plt.title([labels_fine[y_train_fine[i]] ])
    plt.axis('off')
plt.show()
plt.figure(figsize=(10, 10))

for i in range(cant):
    plt.subplot(1, cant, i+1)
    plt.imshow(x_train[i+cant]) #Display the image at index i + cant in x_train
    plt.title([labels_fine[y_train_fine[i+cant]]])
    plt.axis('off')

# %%
len(x_train)
# Out:
# 50000

# %%
x_train[0].ndim
# Out:
# 3

# %%
from sklearn.model_selection import train_test_split
x_split_train, x_split_val, y_split_train, y_split_val = train_test_split(x_train, y_train_fine, test_size=0.2, stratify=y_train_fine)

# %%
print(len(x_split_train))
print(len(x_split_val))
print(len(y_split_train))
print(len(y_split_val))
# Out:
# 40000
# 10000
# 40000
# 10000

# %%
plt.figure(figsize=(10, 10))
cant = 8
for i in range(cant):
    plt.subplot(1, cant, i+1)
    plt.imshow(x_split_train[i]) #Display the i-th image from the training set
    plt.title([labels_fine[y_split_train[i]] ])
    plt.axis('off')
plt.show()
plt.figure(figsize=(10, 10))

for i in range(cant):
    plt.subplot(1, cant, i+1)
    plt.imshow(x_split_train[i+cant]) #Display the image at index i + cant in x_split_train
    plt.title([labels_fine[y_split_train[i+cant]]])
    plt.axis('off')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GaussianNoise, BatchNormalization, Flatten, Input, Rescaling, Conv2D, Conv1D, MaxPooling1D, MaxPooling2D, Normalization, RandomBrightness, RandomFlip, RandomContrast, RandomFlip, RandomRotation, RandomCrop
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.initializers import RandomNormal, Constant
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, TensorBoard
import matplotlib.pyplot as plt

# %%
model = Sequential()
model.add(Input((32,32,3)))
model.add(Normalization())
branch = Sequential()

model.add(Conv2D(128, 3, padding="same", activation="selu"))
model.add(BatchNormalization())
model.add(Conv2D(128, 3, padding="same", activation="selu"))
model.add(BatchNormalization())
model.add(Conv2D(128, 3, padding="same", activation="selu"))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(GaussianNoise(0.3))


model.add(Conv2D(256, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(256, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(256, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.35))

model.add(GaussianNoise(0.3))

model.add(Conv2D(512, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(512, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(512, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(GaussianNoise(0.3))

model.add(Conv2D(1024, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(1024, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(1024, 3, padding="same", activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(GaussianNoise(0.2))

model.add(Flatten())

model.add(Dense(1024, activation="selu", kernel_regularizer=L2(1e-4)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(512, activation="selu", kernel_regularizer=L2(1e-4)))
model.add(Dropout(0.4))
model.add(BatchNormalization(momentum=0.95, 
        epsilon=0.005,
        beta_initializer=RandomNormal(mean=0.0, stddev=0.05), 
        gamma_initializer=Constant(value=0.9)))
model.add(Dense(100, activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy", metrics = ["accuracy"], optimizer = Adam(learning_rate=0.001))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 32, 32, 3)      │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_1                │ (None, 8, 8, 256)      │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_2                │ (None, 4, 4, 512)      │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 4, 4, 1024)     │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 4, 4, 1024)     │     9,438,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 4, 4, 1024)     │     9,438,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_3                │ (None, 2, 2, 1024)     │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     4,195,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │        51,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36,070,507 (137.60 MB)
#  Trainable params: 36,055,908 (137.54 MB)
#  Non-trainable params: 14,599 (57.03 KB)

# %%
# Sets up learning rate reduction on plateau to optimize training stability.

rlrop = ReduceLROnPlateau(
    monitor="val_accuracy",  # Monitors validation accuracy to detect plateaus
    factor=0.5,              # Reduces the learning rate by half when plateauing
    patience=3,              # Waits for 3 epochs without improvement before reducing the learning rate
    verbose=1,               # Enables detailed output for each reduction in learning rate
    min_lr=1e-5              # Defines a minimum learning rate to prevent over-reduction
)

# %%
# Sets up a model checkpoint to save the best weights during training.

mc = ModelCheckpoint(
    "best_weights.weights.h5",   # Path to save the model weights file.
    monitor="val_accuracy",      # Monitors validation accuracy to determine when to save
    verbose=1,                   # Prints a message each time the model weights are saved
    save_best_only=True,         # Saves only if validation accuracy improves, keeping the best weights
    save_weights_only=True       # Saves only the model weights, not the full model
)

# %%
# Sets up early stopping to monitor the validation accuracy during training.

es = EarlyStopping(
    monitor="val_accuracy",       # Tracks validation accuracy to determine stopping point
    patience=10,                  # High patience value (40 epochs) to enable longer training
    verbose=1,                    # Prints messages to indicate when early stopping is triggered
    restore_best_weights=True     # Restores model weights from the best validation accuracy epoch
)

# %%
tb = TensorBoard(
    log_dir="logs",
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
            featurewise_center=False,  
            samplewise_center=False,  
            featurewise_std_normalization=False,  
            samplewise_std_normalization=False,  
            zca_whitening=False, 
            rotation_range=0,
            width_shift_range=0.1,
            height_shift_range=0.1,
            horizontal_flip=True,
            vertical_flip=False)

datagen.fit(x_split_train)

# %%
# Trains the model using the fit method and logs the training history.

history = model.fit(
    datagen.flow(x_split_train, y_split_train, batch_size=64),
    steps_per_epoch=x_split_train.shape[0]//50,                               
    epochs=100,                                     # Specifies the maximum number of training epochs.
    validation_data=(x_split_val, y_split_val),       # Uses validation set to track the model’s performance.
    callbacks=[                                     
        rlrop,  # Reduces learning rate on plateau if validation performance stops improving
        es,     # Implements early stopping with patience, restoring the best weights
        mc,     # Saves the model weights when the best validation accuracy is reached
        tb,     # Enables tensorboard logging for visualizing the training process
    ]
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732918888.844037      80 service.cc:145] XLA service 0x79771800c8f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732918888.844129      80 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732918911.499152      80 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_7', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_5', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_4', 4 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1732918911.531542      80 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.0418 - loss: 5.3651
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 1: val_accuracy improved from -inf to 0.09550, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 76s 56ms/step - accuracy: 0.0457 - loss: 5.3046 - val_accuracy: 0.0955 - val_loss: 4.6831 - learning_rate: 0.0010
# Epoch 2/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.1038 - loss: 4.5353
# Epoch 2: val_accuracy improved from 0.09550 to 0.12440, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.1064 - loss: 4.5101 - val_accuracy: 0.1244 - val_loss: 4.4356 - learning_rate: 0.0010
# Epoch 3/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.1475 - loss: 4.1276
# Epoch 3: val_accuracy improved from 0.12440 to 0.16330, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.1491 - loss: 4.1178 - val_accuracy: 0.1633 - val_loss: 4.0665 - learning_rate: 0.0010
# Epoch 4/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.1842 - loss: 3.9222
# Epoch 4: val_accuracy did not improve from 0.16330
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.1852 - loss: 3.9167 - val_accuracy: 0.1608 - val_loss: 4.4083 - learning_rate: 0.0010
# Epoch 5/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.2192 - loss: 3.7982
# Epoch 5: val_accuracy improved from 0.16330 to 0.23380, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.2200 - loss: 3.7959 - val_accuracy: 0.2338 - val_loss: 3.8144 - learning_rate: 0.0010
# Epoch 6/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.2465 - loss: 3.7282
# Epoch 6: val_accuracy improved from 0.23380 to 0.25010, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.2477 - loss: 3.7269 - val_accuracy: 0.2501 - val_loss: 3.7479 - learning_rate: 0.0010
# Epoch 7/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.2691 - loss: 3.7089
# Epoch 7: val_accuracy improved from 0.25010 to 0.26600, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.2702 - loss: 3.7075 - val_accuracy: 0.2660 - val_loss: 3.7606 - learning_rate: 0.0010
# Epoch 8/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.2892 - loss: 3.6766
# Epoch 8: val_accuracy improved from 0.26600 to 0.29900, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.2900 - loss: 3.6765 - val_accuracy: 0.2990 - val_loss: 3.7148 - learning_rate: 0.0010
# Epoch 9/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.3187 - loss: 3.5946
# Epoch 9: val_accuracy improved from 0.29900 to 0.34280, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.3189 - loss: 3.5994 - val_accuracy: 0.3428 - val_loss: 3.4975 - learning_rate: 0.0010
# Epoch 10/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.3338 - loss: 3.5599
# Epoch 10: val_accuracy did not improve from 0.34280
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.3345 - loss: 3.5626 - val_accuracy: 0.3105 - val_loss: 3.8148 - learning_rate: 0.0010
# Epoch 11/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.3605 - loss: 3.5193
# Epoch 11: val_accuracy improved from 0.34280 to 0.34820, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.3605 - loss: 3.5208 - val_accuracy: 0.3482 - val_loss: 3.5430 - learning_rate: 0.0010
# Epoch 12/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.3816 - loss: 3.4324
# Epoch 12: val_accuracy did not improve from 0.34820
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.3813 - loss: 3.4367 - val_accuracy: 0.3450 - val_loss: 3.5890 - learning_rate: 0.0010
# Epoch 13/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.3934 - loss: 3.4021
# Epoch 13: val_accuracy improved from 0.34820 to 0.40050, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.3937 - loss: 3.4009 - val_accuracy: 0.4005 - val_loss: 3.3666 - learning_rate: 0.0010
# Epoch 14/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.4183 - loss: 3.3230
# Epoch 14: val_accuracy improved from 0.40050 to 0.41190, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.4178 - loss: 3.3239 - val_accuracy: 0.4119 - val_loss: 3.3739 - learning_rate: 0.0010
# Epoch 15/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.4399 - loss: 3.2499
# Epoch 15: val_accuracy improved from 0.41190 to 0.44300, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.4385 - loss: 3.2521 - val_accuracy: 0.4430 - val_loss: 3.1760 - learning_rate: 0.0010
# Epoch 16/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.4453 - loss: 3.2047
# Epoch 16: val_accuracy improved from 0.44300 to 0.44510, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.4448 - loss: 3.2057 - val_accuracy: 0.4451 - val_loss: 3.2107 - learning_rate: 0.0010
# Epoch 17/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.4669 - loss: 3.1181
# Epoch 17: val_accuracy improved from 0.44510 to 0.45210, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.4660 - loss: 3.1227 - val_accuracy: 0.4521 - val_loss: 3.1995 - learning_rate: 0.0010
# Epoch 18/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.4784 - loss: 3.0529
# Epoch 18: val_accuracy improved from 0.45210 to 0.47390, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.4774 - loss: 3.0596 - val_accuracy: 0.4739 - val_loss: 3.1014 - learning_rate: 0.0010
# Epoch 19/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.4884 - loss: 3.0108
# Epoch 19: val_accuracy did not improve from 0.47390
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.4879 - loss: 3.0167 - val_accuracy: 0.4636 - val_loss: 3.1387 - learning_rate: 0.0010
# Epoch 20/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5006 - loss: 2.9800
# Epoch 20: val_accuracy did not improve from 0.47390
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.5010 - loss: 2.9836 - val_accuracy: 0.4691 - val_loss: 3.2333 - learning_rate: 0.0010
# Epoch 21/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5162 - loss: 2.9060
# Epoch 21: val_accuracy improved from 0.47390 to 0.48910, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.5146 - loss: 2.9159 - val_accuracy: 0.4891 - val_loss: 3.0629 - learning_rate: 0.0010
# Epoch 22/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.5265 - loss: 2.8748
# Epoch 22: val_accuracy improved from 0.48910 to 0.49350, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.5241 - loss: 2.8854 - val_accuracy: 0.4935 - val_loss: 3.0593 - learning_rate: 0.0010
# Epoch 23/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5288 - loss: 2.8662
# Epoch 23: val_accuracy did not improve from 0.49350
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.5284 - loss: 2.8693 - val_accuracy: 0.4881 - val_loss: 3.1352 - learning_rate: 0.0010
# Epoch 24/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.5484 - loss: 2.8093
# Epoch 24: val_accuracy improved from 0.49350 to 0.52070, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.5463 - loss: 2.8177 - val_accuracy: 0.5207 - val_loss: 2.9541 - learning_rate: 0.0010
# Epoch 25/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5533 - loss: 2.7865
# Epoch 25: val_accuracy did not improve from 0.52070
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.5510 - loss: 2.7949 - val_accuracy: 0.4968 - val_loss: 3.0879 - learning_rate: 0.0010
# Epoch 26/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5568 - loss: 2.7656
# Epoch 26: val_accuracy did not improve from 0.52070
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.5558 - loss: 2.7709 - val_accuracy: 0.4999 - val_loss: 3.0492 - learning_rate: 0.0010
# Epoch 27/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.5626 - loss: 2.7498
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: val_accuracy did not improve from 0.52070
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.5615 - loss: 2.7548 - val_accuracy: 0.5080 - val_loss: 3.0469 - learning_rate: 0.0010
# Epoch 28/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6178 - loss: 2.4886
# Epoch 28: val_accuracy improved from 0.52070 to 0.59210, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.6192 - loss: 2.4767 - val_accuracy: 0.5921 - val_loss: 2.5493 - learning_rate: 5.0000e-04
# Epoch 29/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6414 - loss: 2.2764
# Epoch 29: val_accuracy did not improve from 0.59210
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.6398 - loss: 2.2792 - val_accuracy: 0.5656 - val_loss: 2.6362 - learning_rate: 5.0000e-04
# Epoch 30/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.6519 - loss: 2.1837
# Epoch 30: val_accuracy improved from 0.59210 to 0.59300, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.6510 - loss: 2.1855 - val_accuracy: 0.5930 - val_loss: 2.4395 - learning_rate: 5.0000e-04
# Epoch 31/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6610 - loss: 2.1284
# Epoch 31: val_accuracy improved from 0.59300 to 0.61940, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.6596 - loss: 2.1323 - val_accuracy: 0.6194 - val_loss: 2.2977 - learning_rate: 5.0000e-04
# Epoch 32/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6697 - loss: 2.0614
# Epoch 32: val_accuracy did not improve from 0.61940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.6681 - loss: 2.0675 - val_accuracy: 0.6128 - val_loss: 2.3245 - learning_rate: 5.0000e-04
# Epoch 33/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6771 - loss: 2.0193
# Epoch 33: val_accuracy did not improve from 0.61940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.6748 - loss: 2.0280 - val_accuracy: 0.6056 - val_loss: 2.3305 - learning_rate: 5.0000e-04
# Epoch 34/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.6811 - loss: 2.0100
# Epoch 34: val_accuracy improved from 0.61940 to 0.63340, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.6801 - loss: 2.0123 - val_accuracy: 0.6334 - val_loss: 2.2420 - learning_rate: 5.0000e-04
# Epoch 35/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.6906 - loss: 1.9703
# Epoch 35: val_accuracy did not improve from 0.63340
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.6891 - loss: 1.9753 - val_accuracy: 0.6270 - val_loss: 2.2701 - learning_rate: 5.0000e-04
# Epoch 36/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.6949 - loss: 1.9422
# Epoch 36: val_accuracy did not improve from 0.63340
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.6932 - loss: 1.9485 - val_accuracy: 0.6178 - val_loss: 2.3163 - learning_rate: 5.0000e-04
# Epoch 37/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7012 - loss: 1.9257
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_accuracy did not improve from 0.63340
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.6991 - loss: 1.9321 - val_accuracy: 0.6312 - val_loss: 2.2509 - learning_rate: 5.0000e-04
# Epoch 38/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7328 - loss: 1.7804
# Epoch 38: val_accuracy improved from 0.63340 to 0.65580, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.7339 - loss: 1.7739 - val_accuracy: 0.6558 - val_loss: 2.1172 - learning_rate: 2.5000e-04
# Epoch 39/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7602 - loss: 1.6497
# Epoch 39: val_accuracy improved from 0.65580 to 0.66260, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.7586 - loss: 1.6526 - val_accuracy: 0.6626 - val_loss: 2.0710 - learning_rate: 2.5000e-04
# Epoch 40/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7646 - loss: 1.5904
# Epoch 40: val_accuracy improved from 0.66260 to 0.66640, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.7631 - loss: 1.5944 - val_accuracy: 0.6664 - val_loss: 2.0236 - learning_rate: 2.5000e-04
# Epoch 41/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7682 - loss: 1.5579
# Epoch 41: val_accuracy did not improve from 0.66640
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.7675 - loss: 1.5594 - val_accuracy: 0.6581 - val_loss: 2.0864 - learning_rate: 2.5000e-04
# Epoch 42/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7769 - loss: 1.5118
# Epoch 42: val_accuracy improved from 0.66640 to 0.66860, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.7754 - loss: 1.5157 - val_accuracy: 0.6686 - val_loss: 2.0212 - learning_rate: 2.5000e-04
# Epoch 43/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7747 - loss: 1.4951
# Epoch 43: val_accuracy improved from 0.66860 to 0.67030, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.7744 - loss: 1.4961 - val_accuracy: 0.6703 - val_loss: 1.9977 - learning_rate: 2.5000e-04
# Epoch 44/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7852 - loss: 1.4563
# Epoch 44: val_accuracy improved from 0.67030 to 0.67790, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.7840 - loss: 1.4599 - val_accuracy: 0.6779 - val_loss: 1.9733 - learning_rate: 2.5000e-04
# Epoch 45/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.7888 - loss: 1.4359
# Epoch 45: val_accuracy did not improve from 0.67790
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.7878 - loss: 1.4391 - val_accuracy: 0.6679 - val_loss: 2.0202 - learning_rate: 2.5000e-04
# Epoch 46/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.7900 - loss: 1.4171
# Epoch 46: val_accuracy did not improve from 0.67790
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.7900 - loss: 1.4191 - val_accuracy: 0.6696 - val_loss: 2.0178 - learning_rate: 2.5000e-04
# Epoch 47/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8013 - loss: 1.3771
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 47: val_accuracy did not improve from 0.67790
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8002 - loss: 1.3817 - val_accuracy: 0.6772 - val_loss: 1.9892 - learning_rate: 2.5000e-04
# Epoch 48/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8162 - loss: 1.3157
# Epoch 48: val_accuracy improved from 0.67790 to 0.68760, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8169 - loss: 1.3126 - val_accuracy: 0.6876 - val_loss: 1.9241 - learning_rate: 1.2500e-04
# Epoch 49/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8328 - loss: 1.2425
# Epoch 49: val_accuracy did not improve from 0.68760
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8326 - loss: 1.2428 - val_accuracy: 0.6862 - val_loss: 1.9312 - learning_rate: 1.2500e-04
# Epoch 50/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8420 - loss: 1.2046
# Epoch 50: val_accuracy did not improve from 0.68760
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8417 - loss: 1.2055 - val_accuracy: 0.6867 - val_loss: 1.9306 - learning_rate: 1.2500e-04
# Epoch 51/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8507 - loss: 1.1697
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 51: val_accuracy did not improve from 0.68760
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8492 - loss: 1.1728 - val_accuracy: 0.6876 - val_loss: 1.9162 - learning_rate: 1.2500e-04
# Epoch 52/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8541 - loss: 1.1317
# Epoch 52: val_accuracy improved from 0.68760 to 0.70150, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8544 - loss: 1.1313 - val_accuracy: 0.7015 - val_loss: 1.8695 - learning_rate: 6.2500e-05
# Epoch 53/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.8601 - loss: 1.1003
# Epoch 53: val_accuracy did not improve from 0.70150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8603 - loss: 1.1006 - val_accuracy: 0.6991 - val_loss: 1.8754 - learning_rate: 6.2500e-05
# Epoch 54/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.8645 - loss: 1.0867
# Epoch 54: val_accuracy did not improve from 0.70150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8648 - loss: 1.0858 - val_accuracy: 0.7003 - val_loss: 1.8724 - learning_rate: 6.2500e-05
# Epoch 55/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8778 - loss: 1.0453
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 55: val_accuracy did not improve from 0.70150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8767 - loss: 1.0481 - val_accuracy: 0.6999 - val_loss: 1.8735 - learning_rate: 6.2500e-05
# Epoch 56/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8781 - loss: 1.0270
# Epoch 56: val_accuracy improved from 0.70150 to 0.70250, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8781 - loss: 1.0272 - val_accuracy: 0.7025 - val_loss: 1.8724 - learning_rate: 3.1250e-05
# Epoch 57/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8775 - loss: 1.0167
# Epoch 57: val_accuracy did not improve from 0.70250
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8780 - loss: 1.0161 - val_accuracy: 0.7015 - val_loss: 1.8709 - learning_rate: 3.1250e-05
# Epoch 58/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8865 - loss: 1.0014
# Epoch 58: val_accuracy improved from 0.70250 to 0.70410, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8862 - loss: 1.0017 - val_accuracy: 0.7041 - val_loss: 1.8613 - learning_rate: 3.1250e-05
# Epoch 59/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8843 - loss: 1.0003
# Epoch 59: val_accuracy did not improve from 0.70410
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8848 - loss: 0.9997 - val_accuracy: 0.7037 - val_loss: 1.8710 - learning_rate: 3.1250e-05
# Epoch 60/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8871 - loss: 0.9857
# Epoch 60: val_accuracy did not improve from 0.70410
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8872 - loss: 0.9856 - val_accuracy: 0.7034 - val_loss: 1.8760 - learning_rate: 3.1250e-05
# Epoch 61/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8897 - loss: 0.9717
# Epoch 61: val_accuracy improved from 0.70410 to 0.70480, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8891 - loss: 0.9729 - val_accuracy: 0.7048 - val_loss: 1.8652 - learning_rate: 3.1250e-05
# Epoch 62/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8907 - loss: 0.9710
# Epoch 62: val_accuracy improved from 0.70480 to 0.70540, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8903 - loss: 0.9712 - val_accuracy: 0.7054 - val_loss: 1.8635 - learning_rate: 3.1250e-05
# Epoch 63/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8943 - loss: 0.9571
# Epoch 63: val_accuracy improved from 0.70540 to 0.70660, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8939 - loss: 0.9575 - val_accuracy: 0.7066 - val_loss: 1.8576 - learning_rate: 3.1250e-05
# Epoch 64/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8966 - loss: 0.9455
# Epoch 64: val_accuracy did not improve from 0.70660
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8958 - loss: 0.9470 - val_accuracy: 0.7040 - val_loss: 1.8730 - learning_rate: 3.1250e-05
# Epoch 65/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8911 - loss: 0.9480
# Epoch 65: val_accuracy improved from 0.70660 to 0.70830, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.8916 - loss: 0.9471 - val_accuracy: 0.7083 - val_loss: 1.8752 - learning_rate: 3.1250e-05
# Epoch 66/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8976 - loss: 0.9330
# Epoch 66: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.8973 - loss: 0.9339 - val_accuracy: 0.7019 - val_loss: 1.8879 - learning_rate: 3.1250e-05
# Epoch 67/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9000 - loss: 0.9235
# Epoch 67: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8995 - loss: 0.9249 - val_accuracy: 0.7046 - val_loss: 1.8784 - learning_rate: 3.1250e-05
# Epoch 68/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8996 - loss: 0.9223
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 68: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.8990 - loss: 0.9230 - val_accuracy: 0.7036 - val_loss: 1.8795 - learning_rate: 3.1250e-05
# Epoch 69/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9000 - loss: 0.9121
# Epoch 69: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9003 - loss: 0.9115 - val_accuracy: 0.7076 - val_loss: 1.8633 - learning_rate: 1.5625e-05
# Epoch 70/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9031 - loss: 0.8973
# Epoch 70: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9031 - loss: 0.8975 - val_accuracy: 0.7077 - val_loss: 1.8647 - learning_rate: 1.5625e-05
# Epoch 71/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9091 - loss: 0.8885
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 71: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9086 - loss: 0.8892 - val_accuracy: 0.7075 - val_loss: 1.8628 - learning_rate: 1.5625e-05
# Epoch 72/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9063 - loss: 0.8869
# Epoch 72: val_accuracy did not improve from 0.70830
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9062 - loss: 0.8873 - val_accuracy: 0.7063 - val_loss: 1.8642 - learning_rate: 1.0000e-05
# Epoch 73/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9074 - loss: 0.8836
# Epoch 73: val_accuracy improved from 0.70830 to 0.70940, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9070 - loss: 0.8843 - val_accuracy: 0.7094 - val_loss: 1.8586 - learning_rate: 1.0000e-05
# Epoch 74/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9074 - loss: 0.8811
# Epoch 74: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9072 - loss: 0.8818 - val_accuracy: 0.7077 - val_loss: 1.8652 - learning_rate: 1.0000e-05
# Epoch 75/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9084 - loss: 0.8820
# Epoch 75: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9087 - loss: 0.8812 - val_accuracy: 0.7078 - val_loss: 1.8644 - learning_rate: 1.0000e-05
# Epoch 76/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9087 - loss: 0.8814
# Epoch 76: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9087 - loss: 0.8809 - val_accuracy: 0.7071 - val_loss: 1.8670 - learning_rate: 1.0000e-05
# Epoch 77/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9070 - loss: 0.8805
# Epoch 77: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9069 - loss: 0.8806 - val_accuracy: 0.7080 - val_loss: 1.8695 - learning_rate: 1.0000e-05
# Epoch 78/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9109 - loss: 0.8658
# Epoch 78: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9106 - loss: 0.8671 - val_accuracy: 0.7072 - val_loss: 1.8693 - learning_rate: 1.0000e-05
# Epoch 79/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9108 - loss: 0.8665
# Epoch 79: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9109 - loss: 0.8661 - val_accuracy: 0.7057 - val_loss: 1.8762 - learning_rate: 1.0000e-05
# Epoch 80/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9064 - loss: 0.8741
# Epoch 80: val_accuracy did not improve from 0.70940
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9068 - loss: 0.8735 - val_accuracy: 0.7092 - val_loss: 1.8743 - learning_rate: 1.0000e-05
# Epoch 81/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9120 - loss: 0.8650
# Epoch 81: val_accuracy improved from 0.70940 to 0.70970, saving model to best_weights.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9120 - loss: 0.8655 - val_accuracy: 0.7097 - val_loss: 1.8699 - learning_rate: 1.0000e-05
# Epoch 82/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9140 - loss: 0.8548
# Epoch 82: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9139 - loss: 0.8559 - val_accuracy: 0.7083 - val_loss: 1.8728 - learning_rate: 1.0000e-05
# Epoch 83/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9126 - loss: 0.8554
# Epoch 83: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9124 - loss: 0.8558 - val_accuracy: 0.7058 - val_loss: 1.8791 - learning_rate: 1.0000e-05
# Epoch 84/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - accuracy: 0.9144 - loss: 0.8509
# Epoch 84: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9143 - loss: 0.8514 - val_accuracy: 0.7090 - val_loss: 1.8731 - learning_rate: 1.0000e-05
# Epoch 85/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9167 - loss: 0.8450
# Epoch 85: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9157 - loss: 0.8473 - val_accuracy: 0.7078 - val_loss: 1.8778 - learning_rate: 1.0000e-05
# Epoch 86/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.9143 - loss: 0.8470
# Epoch 86: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9141 - loss: 0.8479 - val_accuracy: 0.7072 - val_loss: 1.8802 - learning_rate: 1.0000e-05
# Epoch 87/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9154 - loss: 0.8476
# Epoch 87: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9153 - loss: 0.8479 - val_accuracy: 0.7052 - val_loss: 1.8878 - learning_rate: 1.0000e-05
# Epoch 88/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9160 - loss: 0.8412
# Epoch 88: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9157 - loss: 0.8425 - val_accuracy: 0.7081 - val_loss: 1.8776 - learning_rate: 1.0000e-05
# Epoch 89/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9112 - loss: 0.8535
# Epoch 89: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9113 - loss: 0.8531 - val_accuracy: 0.7074 - val_loss: 1.8860 - learning_rate: 1.0000e-05
# Epoch 90/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9199 - loss: 0.8358
# Epoch 90: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9196 - loss: 0.8361 - val_accuracy: 0.7081 - val_loss: 1.8793 - learning_rate: 1.0000e-05
# Epoch 91/100
# 625/800 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9158 - loss: 0.8371
# Epoch 91: val_accuracy did not improve from 0.70970
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9159 - loss: 0.8370 - val_accuracy: 0.7077 - val_loss: 1.8829 - learning_rate: 1.0000e-05
# Epoch 91: early stopping
# Restoring model weights from the end of the best epoch: 81.

# %%
plt.plot(history.history["loss"], label="Train loss")

plt.plot(history.history["val_loss"], label="Validation loss")

plt.legend()

# %%
plt.plot(history.history["accuracy"], label="Train accuracy")

plt.plot(history.history["val_accuracy"], label="Validation accuracy")

plt.legend()

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step

# %%
predictions = predictions.argmax(axis=1)

# %%
predictions
# Out:
# array([68, 33, 55, ..., 51, 42, 70])

# %%
df = pd.DataFrame(predictions, columns=["Label"])

# %%
df.index.name = "Id"

# %%
df.head()
# Out:
#     Label
# Id
# 0      68
# 1      33
# 2      55
# 3      51
# 4      71

# %%
df.to_csv("submission.csv")
